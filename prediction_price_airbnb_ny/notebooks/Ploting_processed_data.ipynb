# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../data/processed/preprocessing_data.csv")

# %%
df.head()
# Out:
#      Id  Quartier  Latitude  Longitude  Type_chambre  Prix  Minimum_nuit  \
# 0  2539       109  40.64749  -73.97237             2   149             1
# 1  2595       128  40.75362  -73.98377             1   225             1
# 2  3647        95  40.80902  -73.94190             2   150             3
# 3  3831        42  40.68514  -73.95976             1    89             1
# 4  5022        62  40.79851  -73.94399             1    80            10
#
#    Avis_par_mois  Nombre_list_hote  Depart_Brooklyn  Depart_Manhattan  \
# 0           0.21                 6                0                 1
# 1           0.38                 2                0                 0
# 2           0.00                 1                0                 0
# 3           4.64                 1                0                 1
# 4           0.10                 1                0                 0
#
#    Depart_Queens  Depart_Staten Island  Depart_Bronx  \
# ...

# %%
df1 = pd.read_csv("../data/raw/AB_NYC_2019.csv")
df1.shape
# Out:
# (48895, 16)
